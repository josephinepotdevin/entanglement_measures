# %%
# %run entanglement_utils.py

# %%
ghz = np.array([1, 0, 0, 1]) / np.sqrt(2)
ghz = np.outer(ghz, ghz)
print(ghz)
# Out:
# [[0.5 0.  0.  0.5]
#  [0.  0.  0.  0. ]
#  [0.  0.  0.  0. ]
#  [0.5 0.  0.  0.5]]

# %%
min = fdecwit(ghz, [2, 2])
print(min[0])
# Out:
# -0.49999986608699265

# %%
psi1 = np.zeros(3**3)
psi1[0] = 1
psi1[13] = 1
psi1[-1] = 1
psi1 = np.outer(psi1,psi1)

# %%
min = fdecwit(psi1, [3, 3, 3])
print(min[0])
# Out:
# -0.33333330878827705

# %%
Wstate = np.array([0, 1, 1, 0, 1, 0, 0, 0]/np.sqrt(3))
Wstate = np.outer(Wstate, Wstate)
min = fdecwit(Wstate, [2, 2, 2])
print(min[0])
